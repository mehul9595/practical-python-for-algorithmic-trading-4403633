# %% [markdown]
# # Challenge: Backtest on Other Datasets

# %% [markdown]
# ## Download data from `yfinance`

# %%
import yfinance as yf

ticker = 'NFLX'
df = yf.download(ticker)
df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2002-05-23    1.156429    1.242857    1.145714    1.196429    1.196429
# 2002-05-24    1.214286    1.225000    1.197143    1.210000    1.210000
# 2002-05-28    1.213571    1.232143    1.157143    1.157143    1.157143
# 2002-05-29    1.164286    1.164286    1.085714    1.103571    1.103571
# 2002-05-30    1.107857    1.107857    1.071429    1.071429    1.071429
# ...                ...         ...         ...         ...         ...
# 2024-03-18  613.559998  627.409973  610.450012  618.390015  618.390015
# 2024-03-19  615.619995  621.280029  608.000000  620.739990  620.739990
# 2024-03-20  619.950012  629.510010  618.340027  627.690002  627.690002
# 2024-03-21  630.650024  634.359985  622.330017  622.710022  622.710022
# 2024-03-22  624.159973  629.049988  621.000000  628.010010  628.010010
#
#                Volume
# Date
# 2002-05-23  104790000
# 2002-05-24   11104800
# 2002-05-28    6609400
# 2002-05-29    6757800
# 2002-05-30   10154200
# ...               ...
# 2024-03-18    3344200
# 2024-03-19    2142600
# 2024-03-20    2639500
# 2024-03-21    2507700
# 2024-03-22    2134100
#
# [5496 rows x 6 columns]

# %% [markdown]
# ## Preprocess the data

# %% [markdown]
# ### Filter the date range
#
# - Since 1 year ago at least

# %%
df = df.loc['2020-01-01':].copy()
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-02  326.100006  329.980011  324.779999  329.809998  329.809998
# 2020-01-03  326.779999  329.859985  325.529999  325.899994  325.899994
# 2020-01-06  323.119995  336.359985  321.200012  335.829987  335.829987
# 2020-01-07  336.470001  336.700012  330.299988  330.750000  330.750000
# 2020-01-08  331.489990  342.700012  331.049988  339.260010  339.260010
# ...                ...         ...         ...         ...         ...
# 2024-03-18  613.559998  627.409973  610.450012  618.390015  618.390015
# 2024-03-19  615.619995  621.280029  608.000000  620.739990  620.739990
# 2024-03-20  619.950012  629.510010  618.340027  627.690002  627.690002
# 2024-03-21  630.650024  634.359985  622.330017  622.710022  622.710022
# 2024-03-22  624.159973  629.049988  621.000000  628.010010  628.010010
#
#              Volume
# Date
# 2020-01-02  4485800
# 2020-01-03  3806900
# 2020-01-06  5663100
# 2020-01-07  4703200
# 2020-01-08  7104500
# ...             ...
# 2024-03-18  3344200
# 2024-03-19  2142600
# 2024-03-20  2639500
# 2024-03-21  2507700
# 2024-03-22  2134100
#
# [1063 rows x 6 columns]

# %% [markdown]
# ### Create the target variable
#
# #### Percentage change
#
# - Percentage change on `Adj Close` for tomorrow

# %%
df['change_tomorrow'] = df['Adj Close'].pct_change(-1)
df.change_tomorrow
# Out:
# Date
# 2020-01-02    0.011998
# 2020-01-03   -0.029569
# 2020-01-06    0.015359
# 2020-01-07   -0.025084
# 2020-01-08    0.010725
#                 ...
# 2024-03-18   -0.003786
# 2024-03-19   -0.011072
# 2024-03-20    0.007997
# 2024-03-21   -0.008439
# 2024-03-22         NaN
# Name: change_tomorrow, Length: 1063, dtype: float64

# %% [markdown]
# If you look at the change from the first day to the next one, the price decreases. Therefore, the first value of the previous output should be negative.

# %%
df['Adj Close']
# Out:
# Date
# 2020-01-02    329.809998
# 2020-01-03    325.899994
# 2020-01-06    335.829987
# 2020-01-07    330.750000
# 2020-01-08    339.260010
#                  ...
# 2024-03-18    618.390015
# 2024-03-19    620.739990
# 2024-03-20    627.690002
# 2024-03-21    622.710022
# 2024-03-22    628.010010
# Name: Adj Close, Length: 1063, dtype: float64

# %% [markdown]
# We shall multiply by -1:

# %%
df.change_tomorrow = df.change_tomorrow * -1
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-02  326.100006  329.980011  324.779999  329.809998  329.809998
# 2020-01-03  326.779999  329.859985  325.529999  325.899994  325.899994
# 2020-01-06  323.119995  336.359985  321.200012  335.829987  335.829987
# 2020-01-07  336.470001  336.700012  330.299988  330.750000  330.750000
# 2020-01-08  331.489990  342.700012  331.049988  339.260010  339.260010
# ...                ...         ...         ...         ...         ...
# 2024-03-18  613.559998  627.409973  610.450012  618.390015  618.390015
# 2024-03-19  615.619995  621.280029  608.000000  620.739990  620.739990
# 2024-03-20  619.950012  629.510010  618.340027  627.690002  627.690002
# 2024-03-21  630.650024  634.359985  622.330017  622.710022  622.710022
# 2024-03-22  624.159973  629.049988  621.000000  628.010010  628.010010
#
#              Volume  change_tomorrow
# Date
# 2020-01-02  4485800        -0.011998
# 2020-01-03  3806900         0.029569
# 2020-01-06  5663100        -0.015359
# 2020-01-07  4703200         0.025084
# 2020-01-08  7104500        -0.010725
# ...             ...              ...
# 2024-03-18  3344200         0.003786
# 2024-03-19  2142600         0.011072
# 2024-03-20  2639500        -0.007997
# 2024-03-21  2507700         0.008439
# 2024-03-22  2134100              NaN
#
# [1063 rows x 7 columns]

# %% [markdown]
# To better read the data, we shall multiply by 100 to have percentage values:

# %%
df.change_tomorrow = df.change_tomorrow * 100
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-02  326.100006  329.980011  324.779999  329.809998  329.809998
# 2020-01-03  326.779999  329.859985  325.529999  325.899994  325.899994
# 2020-01-06  323.119995  336.359985  321.200012  335.829987  335.829987
# 2020-01-07  336.470001  336.700012  330.299988  330.750000  330.750000
# 2020-01-08  331.489990  342.700012  331.049988  339.260010  339.260010
# ...                ...         ...         ...         ...         ...
# 2024-03-18  613.559998  627.409973  610.450012  618.390015  618.390015
# 2024-03-19  615.619995  621.280029  608.000000  620.739990  620.739990
# 2024-03-20  619.950012  629.510010  618.340027  627.690002  627.690002
# 2024-03-21  630.650024  634.359985  622.330017  622.710022  622.710022
# 2024-03-22  624.159973  629.049988  621.000000  628.010010  628.010010
#
#              Volume  change_tomorrow
# Date
# 2020-01-02  4485800        -1.199756
# 2020-01-03  3806900         2.956851
# 2020-01-06  5663100        -1.535899
# 2020-01-07  4703200         2.508403
# 2020-01-08  7104500        -1.072516
# ...             ...              ...
# 2024-03-18  3344200         0.378576
# 2024-03-19  2142600         1.107236
# 2024-03-20  2639500        -0.799727
# 2024-03-21  2507700         0.843934
# 2024-03-22  2134100              NaN
#
# [1063 rows x 7 columns]

# %% [markdown]
# #### Drop rows with any missing data

# %%
df = df.dropna().copy()
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-02  326.100006  329.980011  324.779999  329.809998  329.809998
# 2020-01-03  326.779999  329.859985  325.529999  325.899994  325.899994
# 2020-01-06  323.119995  336.359985  321.200012  335.829987  335.829987
# 2020-01-07  336.470001  336.700012  330.299988  330.750000  330.750000
# 2020-01-08  331.489990  342.700012  331.049988  339.260010  339.260010
# ...                ...         ...         ...         ...         ...
# 2024-03-15  622.919983  622.919983  603.820007  605.880005  605.880005
# 2024-03-18  613.559998  627.409973  610.450012  618.390015  618.390015
# 2024-03-19  615.619995  621.280029  608.000000  620.739990  620.739990
# 2024-03-20  619.950012  629.510010  618.340027  627.690002  627.690002
# 2024-03-21  630.650024  634.359985  622.330017  622.710022  622.710022
#
#              Volume  change_tomorrow
# Date
# 2020-01-02  4485800        -1.199756
# 2020-01-03  3806900         2.956851
# 2020-01-06  5663100        -1.535899
# 2020-01-07  4703200         2.508403
# 2020-01-08  7104500        -1.072516
# ...             ...              ...
# 2024-03-15  6670900         2.022997
# 2024-03-18  3344200         0.378576
# 2024-03-19  2142600         1.107236
# 2024-03-20  2639500        -0.799727
# 2024-03-21  2507700         0.843934
#
# [1062 rows x 7 columns]

# %% [markdown]
# #### BONUS: how to interpret the distribution of a continuous variable

# %% [markdown]
# Based on the following normal distribution:

# %%
df.change_tomorrow.hist(bins=range(-15,15), edgecolor='black');

# %% [markdown]
# And the standard deviation:

# %%
df.change_tomorrow.std()
# Out:
# 3.2838049999228316

# %% [markdown]
# We can say that 68% of the changes are between -3.5 and 3.5, approximately.

# %% [markdown]
# #### Change sign
#
# Did the stock go up or down?

# %%
import numpy as np

# %%
df.change_tomorrow = np.where(df.change_tomorrow > 0, 1, -1)
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-02  326.100006  329.980011  324.779999  329.809998  329.809998
# 2020-01-03  326.779999  329.859985  325.529999  325.899994  325.899994
# 2020-01-06  323.119995  336.359985  321.200012  335.829987  335.829987
# 2020-01-07  336.470001  336.700012  330.299988  330.750000  330.750000
# 2020-01-08  331.489990  342.700012  331.049988  339.260010  339.260010
# ...                ...         ...         ...         ...         ...
# 2024-03-15  622.919983  622.919983  603.820007  605.880005  605.880005
# 2024-03-18  613.559998  627.409973  610.450012  618.390015  618.390015
# 2024-03-19  615.619995  621.280029  608.000000  620.739990  620.739990
# 2024-03-20  619.950012  629.510010  618.340027  627.690002  627.690002
# 2024-03-21  630.650024  634.359985  622.330017  622.710022  622.710022
#
#              Volume  change_tomorrow
# Date
# 2020-01-02  4485800               -1
# 2020-01-03  3806900                1
# 2020-01-06  5663100               -1
# 2020-01-07  4703200                1
# 2020-01-08  7104500               -1
# ...             ...              ...
# 2024-03-15  6670900                1
# 2024-03-18  3344200                1
# 2024-03-19  2142600                1
# 2024-03-20  2639500               -1
# 2024-03-21  2507700                1
#
# [1062 rows x 7 columns]

# %% [markdown]
# ## Compute Machine Learning model
#
# Proposal: Random Forest within `ensemble` module of `sklearn` library

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier(max_depth=7, random_state=42)

# %%
y = df.change_tomorrow
X = df.drop(columns='change_tomorrow')

# %%
model.fit(X, y)
# Out:
# RandomForestClassifier(max_depth=7, random_state=42)

# %%
model.score(X, y)
# Out:
# 0.8349056603773585

# %% [markdown]
# ## Backtesting

# %% [markdown]
# ### Create the strategy

# %%
from backtesting import Strategy

# %%
class SimpleClassificationUD(Strategy):
    def init(self):
        self.model = model
        self.already_bought = False

    def next(self):
        explanatory_today = self.data.df.iloc[-1:, :]
        forecast_tomorrow = self.model.predict(explanatory_today)[0]
        
        # conditions to sell or buy
        if forecast_tomorrow == 1 and self.already_bought == False:
            self.buy()
            self.already_bought = True
        elif forecast_tomorrow == -1 and self.already_bought == True:
            self.sell()
            self.already_bought = False
        else:
            pass

# %% [markdown]
# ### Run the Backtest

# %%
from backtesting import Backtest

# %%
bt = Backtest(
    X, SimpleClassificationUD, cash=10000,
    commission=.002, exclusive_orders=True
)

# %%
results = bt.run()

# %% [markdown]
# ### Show the report in a DataFrame

# %%
results.to_frame('Value').loc[:'Return [%]']
# Out:
#                                  Value
# Start              2020-01-02 00:00:00
# End                2023-05-15 00:00:00
# Duration            1229 days 00:00:00
# Exposure Time [%]            99.764151
# Equity Final [$]       28916881.488771
# Equity Peak [$]        28977622.433596
# Return [%]               289068.814888

# %% [markdown]
# ## Plot the backtest report

# %% [markdown]
# > Don't worry about this new tool just yet, we will explain in a future chapter how to interpret the following chart.

# %%
bt.plot(filename='backtest_report.html')
# Out:
# Row(id='1407', ...)

# %% [markdown]
# ## How to invest based on the numerical increase?
#
# > Instead of the direction (UP or DOWN)
#
# Next chapter → [Backtesting with Regression Models]()

# %% [markdown]
# Classification Model | Regression Model
# -|-
# ![](src/pred_classification.png) | ![](src/pred_regression.png)

# %% [markdown]
# Classification Strategy | Regression Strategy
# -|-
# ![](src/res_classification.png) | ![](src/res_regression.png)
